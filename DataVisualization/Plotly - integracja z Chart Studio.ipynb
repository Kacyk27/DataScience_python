# %%
# !pip install -q chart_studio
# !pip install -q --upgrade plotly
# Out:
#      |████████████████████████████████| 64 kB 952 kB/s
#      |████████████████████████████████| 26.5 MB 1.2 MB/s

# %%
import chart_studio.tools as tls

tls.embed('https://plot.ly/~krakowiakpawel9/19/font-color-4d5663/')
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-7-a713514cbc3b> in <module>()
#       1 import chart_studio.tools as tls
#       2
# ----> 3 tls.embed('https://plot.ly/~krakowiakpawel9/19/font-color-4d5663/')
#
# /usr/local/lib/python3.7/dist-packages/chart_studio/tools.py in embed(file_owner_or_url, file_id, width, height)
#     380             url = file_owner_or_url
#     381
# --> 382         embed_url = _get_embed_url(url, file_id)
#     383         return ipython_display.IFrame(embed_url, width, height)
#     384     else:
#
# /usr/local/lib/python3.7/dist-packages/chart_studio/tools.py in _get_embed_url(file_owner_or_url, file_id)
#     259                 "'{1}'."
#     260                 "\nRun help on this function for more information."
# --> 261                 "".format(url, plotly_rest_url)
#     262             )
#     263         urlsplit = six.moves.urllib.parse.urlparse(url)
#
# PlotlyError: Because you didn't supply a 'file_id' in the call, we're assuming you're trying to snag a figure from a url. You supplied the url, 'https://plot.ly/~krakowiakpawel9/19/font-color-4d5663/', we expected it to start with 'https://plotly.com'.
# Run help on this function for more information.

# %%
import chart_studio.tools as tls
import chart_studio.plotly as py
import plotly.graph_objects as go

# %%
tls.set_credentials_file(username='krakowiakpawel9', api_key='IQzzmPQv5FOopavx5Y3J')

trace0 = go.Scatter(x=[1, 2, 3, 4],
                   y=[5, 5, 10, 15])

data = [trace0]

fig = go.Figure(data=data)

py.iplot(fig, filename='first')
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~krakowiakpawel9/37.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
